# %%
pip install langchain
# Out:
# Requirement already satisfied: langchain in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (0.4.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.12.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.0.23)
# Requirement already satisfied: requests<3,>=2 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (2.27.1)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (2.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.6.2)
# Requirement already satisfied: certifi in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2022.12.7)
# Requirement already satisfied: httpcore==1.* in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: idna in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2.10)
# Requirement already satisfied: sniffio in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (1.26.14)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain) (2.0.12)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -qU "langchain[google-genai]"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = getpass.getpass("Enter API key for Google Gemini: ")

from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.5-flash", model_provider="google_genai")

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage(content="Translate the following from English into Italian"),
    HumanMessage(content="hi!"),
]

model.invoke(messages)
# Out:
# AIMessage(content='Ciao!', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}, id='run--d63bfde9-54c8-4a5f-8d5a-c90a87962263-0', usage_metadata={'input_tokens': 10, 'output_tokens': 36, 'total_tokens': 46, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 34}})
