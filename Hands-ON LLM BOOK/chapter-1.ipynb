# %%
# !pip install "accelerate>=0.26.0"
# Out:
# Requirement already satisfied: accelerate>=0.26.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (1.13.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (24.2)
# Requirement already satisfied: psutil in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (5.9.4)
# Requirement already satisfied: pyyaml in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (6.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (2.2.1)
# Requirement already satisfied: huggingface_hub>=0.21.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (0.35.3)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from accelerate>=0.26.0) (0.6.2)
# Requirement already satisfied: filelock in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (2024.3.0)
# Requirement already satisfied: requests in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from huggingface_hub>=0.21.0->accelerate>=0.26.0) (4.15.0)
# Requirement already satisfied: sympy in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (1.14.0)
# Requirement already satisfied: networkx in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (2.8.8)
# Requirement already satisfied: jinja2 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from torch>=2.0.0->accelerate>=0.26.0) (3.1.2)
# Requirement already satisfied: colorama in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from tqdm>=4.42.1->huggingface_hub>=0.21.0->accelerate>=0.26.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from jinja2->torch>=2.0.0->accelerate>=0.26.0) (2.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from requests->huggingface_hub>=0.21.0->accelerate>=0.26.0) (2022.12.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rajiv singh\appdata\local\programs\python\python311\lib\site-packages (from sympy->torch>=2.0.0->accelerate>=0.26.0) (1.3.0)
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load model and tokenizer
model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=False,
)
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37728\860818917.py in <cell line: 0>()
#       2
#       3 # Load model and tokenizer
# ----> 4 model = AutoModelForCausalLM.from_pretrained(
#       5     "microsoft/Phi-3-mini-4k-instruct",
#       6     device_map="cuda",
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\models\auto\auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562         elif type(config) in cls._model_mapping.keys():
#     563             model_class = _get_model_class(config, cls._model_mapping)
# --> 564             return model_class.from_pretrained(
#     565                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566             )
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    4012                 offload_index,
#    4013                 error_msgs,
# -> 4014             ) = cls._load_pretrained_model(
#    4015                 model,
#    4016                 state_dict,
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py in _load_pretrained_model(cls, model, state_dict, loaded_keys, resolved_archive_file, pretrained_model_name_or_path, ignore_mismatched_sizes, sharded_metadata, _fast_init, low_cpu_mem_usage, device_map, offload_folder, offload_state_dict, dtype, hf_quantizer, keep_in_fp32_modules, gguf_path)
#    4500                                 )
#    4501                     else:
# -> 4502                         new_error_msgs, offload_index, state_dict_index = _load_state_dict_into_meta_model(
#    4503                             model_to_load,
#    4504                             state_dict,
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\transformers\modeling_utils.py in _load_state_dict_into_meta_model(model, state_dict, start_prefix, expected_keys, device_map, offload_folder, offload_index, state_dict_folder, state_dict_index, dtype, hf_quantizer, is_safetensors, keep_in_fp32_modules, unexpected_keys, pretrained_model_name_or_path)
#     971
#     972             # For backward compatibility with older versions of `accelerate` and for non-quantized params
# --> 973             set_module_tensor_to_device(model, param_name, param_device, **set_module_kwargs)
#     974         else:
#     975             hf_quantizer.create_quantized_param(model, param, param_name, param_device, state_dict, unexpected_keys)
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\accelerate\utils\modeling.py in set_module_tensor_to_device(module, tensor_name, device, value, dtype, fp16_statistics, tied_params_map, non_blocking, clear_cache)
#     341                     module._parameters[tensor_name] = param_cls(new_value, requires_grad=old_value.requires_grad)
#     342         elif isinstance(value, torch.Tensor):
# --> 343             new_value = value.to(device, non_blocking=non_blocking)
#     344         else:
#     345             new_value = torch.tensor(value, device=device)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 96.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 3.41 GiB is allocated by PyTorch, and 1.82 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True
